# %%
import yfinance as yf

# Fetch historical data for NIFTY 50 (^NSEI)
nifty50 = yf.Ticker("^NSEI")  # Yahoo Finance symbol for NIFTY 50
df = nifty50.history(period="2y")  # Get 1-year data

# Display DataFrame
print(df)
# Out:
# ---------------------------------------------------------------------------
# YFRateLimitError                          Traceback (most recent call last)
# Cell In[53], line 5
#       3 # Fetch historical data for NIFTY 50 (^NSEI)
#       4 nifty50 = yf.Ticker("^NSEI")  # Yahoo Finance symbol for NIFTY 50
# ----> 5 df = nifty50.history(period="2y")  # Get 1-year data
#       7 # Display DataFrame
#       8 print(df)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\yfinance\utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File C:\ProgramData\anaconda3\Lib\site-packages\yfinance\base.py:81, in TickerBase.history(self, *args, **kwargs)
#      79 @utils.log_indent_decorator
#      80 def history(self, *args, **kwargs) -> pd.DataFrame:
# ...

# %%
nse = Nse()

# %%
print(nse)
# Out:
# Driver Class for National Stock Exchange (NSE)

# %%
nse.get_index_list()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 nse.get_index_list()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nsetools\nse.py:276, in Nse.get_index_list(self, as_json)
#     274 req = Request(url, None, self.headers)
#     275 # raises URLError or HTTPError
# --> 276 resp = self.opener.open(req)
#     277 resp = byte_adaptor(resp)
#     278 resp_list = json.load(resp)['data']
#
# File C:\ProgramData\anaconda3\Lib\urllib\request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File C:\ProgramData\anaconda3\Lib\urllib\request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
# ...
